# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv('712 data.csv')
df
# Out:
#     TERRITORY         MARKET  LOCATION_ID       LOCATION_DESCR  \
# 0       SOUTH  MIDLAND FLAGS          712  MANCHESTER TRAFFORD
# 1       SOUTH  MIDLAND FLAGS          712  MANCHESTER TRAFFORD
# 2       SOUTH  MIDLAND FLAGS          712  MANCHESTER TRAFFORD
# 3       SOUTH  MIDLAND FLAGS          712  MANCHESTER TRAFFORD
# 4       SOUTH  MIDLAND FLAGS          712  MANCHESTER TRAFFORD
# ..        ...            ...          ...                  ...
# 137     SOUTH  MIDLAND FLAGS          712  MANCHESTER TRAFFORD
# 138     SOUTH  MIDLAND FLAGS          712  MANCHESTER TRAFFORD
# 139     SOUTH  MIDLAND FLAGS          712  MANCHESTER TRAFFORD
# 140     SOUTH  MIDLAND FLAGS          712  MANCHESTER TRAFFORD
# 141     SOUTH  MIDLAND FLAGS          712  MANCHESTER TRAFFORD
#
#     DAY_OF_THE_WEEK FITTING_ROOM_AREA TIME_PERIOD  AVERAGE_FR_OCCUPANCY_PCT
# 0         1. Sunday              Mens       13-14                 75.000000
# ...

# %%
df_Mens = df[df['FITTING_ROOM_AREA']=='Mens']

# %%
df_Mens_pv = df_Mens.pivot_table(values = 'AVERAGE_FR_OCCUPANCY_PCT', index = 'DAY_OF_THE_WEEK', columns = 'TIME_PERIOD')

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize = (10,6))
plt.title('Fitting Room Occupancy (%) in Manchester Trafford During Week 24')
sns.heatmap(df_Mens_pv, cmap = 'Oranges', linecolor='white',linewidths=1, annot = True,cbar_kws={'format': '%.0f%%'})
plt.xlabel('Time Period')
plt.ylabel('Day of the Week')
# Out:
# Text(95.72222222222221, 0.5, 'Day of the Week')

# %% [markdown]
# Now looking at the specific number of minutes for each fitting room

# %%
df_mins = pd.read_csv('712 mins data.csv')
df_mins
# Out:
#     TERRITORY         MARKET  LOCATION_ID       LOCATION_DESCR  \
# 0       SOUTH  MIDLAND FLAGS          712  MANCHESTER TRAFFORD
# 1       SOUTH  MIDLAND FLAGS          712  MANCHESTER TRAFFORD
# 2       SOUTH  MIDLAND FLAGS          712  MANCHESTER TRAFFORD
# 3       SOUTH  MIDLAND FLAGS          712  MANCHESTER TRAFFORD
# 4       SOUTH  MIDLAND FLAGS          712  MANCHESTER TRAFFORD
# ..        ...            ...          ...                  ...
# 204     SOUTH  MIDLAND FLAGS          712  MANCHESTER TRAFFORD
# 205     SOUTH  MIDLAND FLAGS          712  MANCHESTER TRAFFORD
# 206     SOUTH  MIDLAND FLAGS          712  MANCHESTER TRAFFORD
# 207     SOUTH  MIDLAND FLAGS          712  MANCHESTER TRAFFORD
# 208     SOUTH  MIDLAND FLAGS          712  MANCHESTER TRAFFORD
#
#     FITTING_ROOM_AREA FITTING_ROOM_NAME DAY_OF_THE_WEEK        DATE  \
# 0                Mens            Mens 1       1. Sunday  2024-06-09
# 1                Mens            Mens 1       1. Sunday  2024-06-09
# ...

# %%
df_Mens_1 = df_mins[df_mins['FITTING_ROOM_NAME'] == 'Mens 1']
df_Mens_2 = df_mins[df_mins['FITTING_ROOM_NAME'] == 'Mens 2']
df_Mens_3 = df_mins[df_mins['FITTING_ROOM_NAME'] == 'Mens 3']

# %%
df_Mens_pv_1 = df_Mens_1.pivot_table(values = 'FR_VISIT_MINS', index = 'DAY_OF_THE_WEEK', columns = 'TIME_PERIOD')
df_Mens_pv_2 = df_Mens_2.pivot_table(values = 'FR_VISIT_MINS', index = 'DAY_OF_THE_WEEK', columns = 'TIME_PERIOD')
df_Mens_pv_3 = df_Mens_3.pivot_table(values = 'FR_VISIT_MINS', index = 'DAY_OF_THE_WEEK', columns = 'TIME_PERIOD')

# %%
plt.figure(figsize = (10,6))
plt.title('Fitting Room Occupancy (mins) - Mens 1')
sns.heatmap(df_Mens_pv_1, cmap = 'Blues', linecolor='white',linewidths=1, annot = True)
plt.xlabel('Time Period')
plt.ylabel('Day of the Week')
# Out:
# Text(95.72222222222221, 0.5, 'Day of the Week')

# %%
plt.figure(figsize = (10,6))
plt.title('Fitting Room Occupancy (mins) - Mens 2')
sns.heatmap(df_Mens_pv_2, cmap = 'Blues', linecolor='white',linewidths=1, annot = True)
plt.xlabel('Time Period')
plt.ylabel('Day of the Week')
# Out:
# Text(95.72222222222221, 0.5, 'Day of the Week')

# %%
plt.figure(figsize = (10,6))
plt.title('Fitting Room Occupancy (mins) - Mens 3')
sns.heatmap(df_Mens_pv_3, cmap = 'Blues', linecolor='white',linewidths=1, annot = True)
plt.xlabel('Time Period')
plt.ylabel('Day of the Week')
# Out:
# Text(95.72222222222221, 0.5, 'Day of the Week')

# %% [markdown]
# Redoing the analysis but YTD (request)

# %%
df_ytd = pd.read_csv('712 YTD data.csv')

# %%
df_ytd
# Out:
#     TERRITORY         MARKET  LOCATION_ID       LOCATION_DESCR  \
# 0       SOUTH  MIDLAND FLAGS          712  MANCHESTER TRAFFORD
# 1       SOUTH  MIDLAND FLAGS          712  MANCHESTER TRAFFORD
# 2       SOUTH  MIDLAND FLAGS          712  MANCHESTER TRAFFORD
# 3       SOUTH  MIDLAND FLAGS          712  MANCHESTER TRAFFORD
# 4       SOUTH  MIDLAND FLAGS          712  MANCHESTER TRAFFORD
# ..        ...            ...          ...                  ...
# 149     SOUTH  MIDLAND FLAGS          712  MANCHESTER TRAFFORD
# 150     SOUTH  MIDLAND FLAGS          712  MANCHESTER TRAFFORD
# 151     SOUTH  MIDLAND FLAGS          712  MANCHESTER TRAFFORD
# 152     SOUTH  MIDLAND FLAGS          712  MANCHESTER TRAFFORD
# 153     SOUTH  MIDLAND FLAGS          712  MANCHESTER TRAFFORD
#
#     DAY_OF_THE_WEEK FITTING_ROOM_AREA TIME_PERIOD  AVERAGE_FR_OCCUPANCY_PCT
# 0         1. Sunday              Mens       12-13                 40.470092
# ...

# %%
df_ytd_mens = df_ytd[df_ytd['FITTING_ROOM_AREA'] == 'Mens']

# %%
df_YTD_Mens_pv = df_ytd_mens.pivot_table(values = 'AVERAGE_FR_OCCUPANCY_PCT', index = 'DAY_OF_THE_WEEK', columns = 'TIME_PERIOD')

# %%
plt.figure(figsize = (10,6))
plt.title('Fitting Room Occupancy (%) in Manchester Trafford YTD Weeks 1 - 25')
sns.heatmap(df_YTD_Mens_pv, cmap = 'Oranges', linecolor='white',linewidths=1, annot = True,cbar_kws={'format': '%.0f%%'})
plt.xlabel('Time Period')
plt.ylabel('Day of the Week')
# Out:
# Text(95.72222222222221, 0.5, 'Day of the Week')

# %%
df_ytd_mins = pd.read_csv('712 YTD data mins.csv')

# %%
df_ytd_mins_men = df_ytd_mins[df_ytd_mins['FITTING_ROOM_AREA'] == 'Mens']

# %%
df_ytd_mins_men
# Out:
#     TERRITORY         MARKET  LOCATION_ID       LOCATION_DESCR  \
# 0       SOUTH  MIDLAND FLAGS          712  MANCHESTER TRAFFORD
# 1       SOUTH  MIDLAND FLAGS          712  MANCHESTER TRAFFORD
# 2       SOUTH  MIDLAND FLAGS          712  MANCHESTER TRAFFORD
# 3       SOUTH  MIDLAND FLAGS          712  MANCHESTER TRAFFORD
# 4       SOUTH  MIDLAND FLAGS          712  MANCHESTER TRAFFORD
# ..        ...            ...          ...                  ...
# 226     SOUTH  MIDLAND FLAGS          712  MANCHESTER TRAFFORD
# 227     SOUTH  MIDLAND FLAGS          712  MANCHESTER TRAFFORD
# 228     SOUTH  MIDLAND FLAGS          712  MANCHESTER TRAFFORD
# 229     SOUTH  MIDLAND FLAGS          712  MANCHESTER TRAFFORD
# 230     SOUTH  MIDLAND FLAGS          712  MANCHESTER TRAFFORD
#
#     FITTING_ROOM_AREA FITTING_ROOM_NAME DAY_OF_THE_WEEK TIME_PERIOD  \
# 0                Mens            Mens 1     7. Saturday       10-11
# 1                Mens            Mens 1      3. Tuesday       10-11
# ...

# %%
df_Mens_1 = df_ytd_mins_men[df_ytd_mins_men['FITTING_ROOM_NAME'] == 'Mens 1']
df_Mens_2 = df_ytd_mins_men[df_ytd_mins_men['FITTING_ROOM_NAME'] == 'Mens 2']
df_Mens_3 = df_ytd_mins_men[df_ytd_mins_men['FITTING_ROOM_NAME'] == 'Mens 3']

# %%
df_Mens_1_pv = df_Mens_1.pivot_table(values = 'FR_VISIT_MINS', index = 'DAY_OF_THE_WEEK', columns = 'TIME_PERIOD')
df_Mens_2_pv = df_Mens_2.pivot_table(values = 'FR_VISIT_MINS', index = 'DAY_OF_THE_WEEK', columns = 'TIME_PERIOD')
df_Mens_3_pv = df_Mens_3.pivot_table(values = 'FR_VISIT_MINS', index = 'DAY_OF_THE_WEEK', columns = 'TIME_PERIOD')

# %%
plt.figure(figsize = (10,6))
plt.title('YTD Average Fitting Room Occupancy (mins) - Mens 1')
sns.heatmap(df_Mens_1_pv, cmap = 'Blues', linecolor='white',linewidths=1, annot = True)
plt.xlabel('Time Period')
plt.ylabel('Day of the Week')
# Out:
# Text(95.72222222222221, 0.5, 'Day of the Week')

# %%
plt.figure(figsize = (10,6))
plt.title('YTD Average Fitting Room Occupancy (mins) - Mens 2')
sns.heatmap(df_Mens_2_pv, cmap = 'Blues', linecolor='white',linewidths=1, annot = True)
plt.xlabel('Time Period')
plt.ylabel('Day of the Week')
# Out:
# Text(95.72222222222221, 0.5, 'Day of the Week')

# %%
plt.figure(figsize = (10,6))
plt.title('YTD Average Fitting Room Occupancy (mins) - Mens 3')
sns.heatmap(df_Mens_3_pv, cmap = 'Blues', linecolor='white',linewidths=1, annot = True)
plt.xlabel('Time Period')
plt.ylabel('Day of the Week')
# Out:
# Text(95.72222222222221, 0.5, 'Day of the Week')
